# %%
import sklearn.datasets

data, color = sklearn.datasets.make_swiss_roll(5000)
data[:,2][:10]
# Out:
# array([ -4.72877924,  -4.7981649 ,  -4.25901758,   6.74592259,
#        -10.18410927,  -4.67567763,  -1.15545219,  -2.42804385,
#         -4.45001045,  -6.29608645])

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(projection='3d')
X = data[:,0]
Y = data[:,1]
Z = data[:,2]
ax.view_init(azim=80, elev=20)
ax.scatter(X, Y, Z, c=color, cmap=plt.cm.seismic)

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(kernel="rbf", fit_inverse_transform=True, gamma=10)
X_kpca = kpca.fit_transform(data)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(projection='3d')
X = X_kpca[:,0]
Y = X_kpca[:,1]
Z = X_kpca[:,2]
ax.view_init(azim=80, elev=20)
ax.scatter(X, Y, Z, c=color, cmap=plt.cm.seismic)

# %%
from sklearn.manifold import LocallyLinearEmbedding
embedding = LocallyLinearEmbedding(n_components=3)
X_lle = embedding.fit_transform(data)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(projection='3d')
X = X_lle[:,0]
Y = X_lle[:,1]
Z = X_lle[:,2]
ax.view_init(azim=80, elev=20)
ax.scatter(X, Y, Z, c=color, cmap=plt.cm.seismic)
